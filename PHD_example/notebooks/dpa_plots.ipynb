# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np

from experiments.plotting import (
    make_as_ss_plots_alignment,
    make_cifar_plots,
    make_alignment_plots,
    make_phrase_level_stability_plots,
    make_phrase_level_validity_plots,
    wc_acc_at_k_plots,
    make_cifar_max_plot,
    make_agt_bagging_blobs_plot,
    make_multi_model_alignment_plots
)

# %%
make_cifar_plots(finetune=True)

# %%
make_cifar_plots(False)

# %%
make_alignment_plots(True, True, model_name="gemma2b", batch_size=50)

# %%
make_alignment_plots(False, True, model_name="gemma2b", batch_size=50)

# %%
make_alignment_plots(True, True, 80)

# %%
wc_acc_at_k_plots(True, [1, 3, 5, 7, 9], batch_size=80)

# %%
make_alignment_plots(False, True, 80)

# %%
wc_acc_at_k_plots(False, [1, 3, 5, 7, 9], batch_size=80)

# %%
make_as_ss_plots_alignment("olmo")

# %%
make_as_ss_plots_alignment("gemma")

# %%
make_as_ss_plots_alignment("qwen")

# %%
make_cifar_max_plot(finetune=True)

# %%
make_cifar_max_plot(finetune=False)

# %%
make_agt_bagging_blobs_plot()

# %%
make_multi_model_alignment_plots(dpa=True, msc=False)

# %%
make_multi_model_alignment_plots(dpa=False, msc=False)

# %%
make_multi_model_alignment_plots(dpa=True, msc=True)

# %%
make_phrase_level_stability_plots("gemma2b")

# %%
make_phrase_level_stability_plots("olmo1b")

# %%
make_phrase_level_validity_plots("gemma2b")

# %%
make_phrase_level_validity_plots("olmo1b")
